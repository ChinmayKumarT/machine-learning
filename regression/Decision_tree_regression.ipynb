# %% [markdown]
# <a href="https://colab.research.google.com/github/ChinmayKumarT/machine-learning/blob/main/Decision_tree_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/Position_Salaries.csv")
x = dataset.iloc[: , 1: -1 ].values
y = dataset.iloc[: , -1 ].values

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor()
reg.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
reg.predict([[6.5]])
# Out:
# array([150000.])

# %%
x_grid = np.arange(min(x) , max(x) , 0.01)
x_grid = x_grid.reshape((len(x_grid),1))
plt.scatter(x , y ,color = "red")
plt.plot(x_grid , reg.predict(x_grid) , color = "blue")
plt.title(" decision tree regressor ")
plt.xlabel(" position ")
plt.ylabel("salaries")
plt.show()
# Out:
# /tmp/ipython-input-408466305.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x) , max(x) , 0.01)
